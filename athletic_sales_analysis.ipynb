# %%
# Import Libraries and Dependencies
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Combine and Clean the Data
# #### Import CSVs

# %%
# Read the CSV files into DataFrames.
sales_2020 = pd.read_csv("Resources/athletic_sales_2020.csv")
sales_2021 = pd.read_csv("Resources/athletic_sales_2021.csv")

# %%
# Display the 2020 sales DataFrame
sales_2020
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732       1/1/20  Northeast      New York
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732       1/1/20  Northeast      New York
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 1292    West Gear      1128299     12/30/20       West    California
# 1293    West Gear      1128299     12/30/20       West    California
# 1294       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1295       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1296    West Gear      1128299     12/30/20       West    California
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %%
# Display the 2021 sales DataFrame
sales_2021
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0       West Gear      1128299       1/1/21       West    California
# 1       West Gear      1128299       1/1/21       West    California
# 2          Kohl's      1189833       1/1/21    Midwest       Montana
# 3          Kohl's      1189833       1/1/21    Midwest       Montana
# 4       West Gear      1128299       1/1/21       West    California
# ...           ...          ...          ...        ...           ...
# 8341  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8342  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8343       Amazon      1185732     12/31/21  Northeast         Maine
# 8344       Amazon      1185732     12/31/21  Northeast         Maine
# 8345  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# #### Check the data types of each DataFrame

# %%
# Check the 2020 sales data types.
print(sales_2020.dtypes)
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Check the 2021 sales data types.
print(sales_2021.dtypes)
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %% [markdown]
# #### Combine the sales data by rows.

# %%
# Combine the 2020 and 2021 sales DataFrames on the rows and reset the index.
combined_sales_df = pd.concat([sales_2020, sales_2021], axis = 0)
combined_sales_df = combined_sales_df.reset_index(drop=True)
combined_sales_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732       1/1/20  Northeast      New York
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732       1/1/20  Northeast      New York
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 9638  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 9639  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 9640       Amazon      1185732     12/31/21  Northeast         Maine
# 9641       Amazon      1185732     12/31/21  Northeast         Maine
# 9642  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#               city                product  price_per_unit  units_sold  \
# ...

# %%
# Check if any values are null.
combined_sales_df.isnull().sum()
# Out:
# retailer            0
# retailer_id         0
# invoice_date        0
# region              0
# state               0
# city                0
# product             0
# price_per_unit      0
# units_sold          0
# total_sales         0
# operating_profit    0
# sales_method        0
# dtype: int64

# %%
# Check the data type of each column
print(combined_sales_df.dtypes)
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Convert the "invoice_date" to a datetime datatype
combined_sales_df['invoice_date'] = pd.to_datetime(combined_sales_df['invoice_date'])
# Out:
# C:\Users\enock\AppData\Local\Temp\ipykernel_6220\2172351529.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   combined_sales_df['invoice_date'] = pd.to_datetime(combined_sales_df['invoice_date'])

# %%
# Confirm that the "invoice_date" data type has been changed.
print(combined_sales_df.dtypes)
# Out:
# retailer                    object
# retailer_id                  int64
# invoice_date        datetime64[ns]
# region                      object
# state                       object
# city                        object
# product                     object
# price_per_unit               int64
# units_sold                   int64
# total_sales                  int64
# operating_profit           float64
# sales_method                object
# dtype: object

# %% [markdown]
# ### 2. Determine which Region Sold the Most Products

# %% [markdown]
# #### Using `groupby`

# %%
# Show the number products sold for region, state, and city.

products_sold_df = combined_sales_df.groupby(['region', 'state', 'city']).size().reset_index()

# Rename the sum to "Total_Products_Sold".

Total_Products_Sold = products_sold_df.rename(columns={'products_sold_df': 'Total_Products_Sold'})

# Show the top 5 results.

Total_Products_Sold.head()
# Out:
#     region     state          city    0
# 0  Midwest  Illinois       Chicago  144
# 1  Midwest   Indiana  Indianapolis  144
# 2  Midwest      Iowa    Des Moines  144
# 3  Midwest    Kansas       Wichita  144
# 4  Midwest  Michigan       Detroit  144

# %% [markdown]
# #### Using `pivot_table`

# %%
units_sold_df = combined_sales_df.pivot_table(values='product', index=['region', 'state', 'city'], aggfunc='sum')
Total_Products_Sold = units_sold_df.rename(columns={'product': 'Total_Products_Sold'})
Total_Products_Sold.head()
# Out:
#                                                              Total_Products_Sold
# region  state    city
# Midwest Illinois Chicago       Men's ApparelMen's ApparelWomen's ApparelWomen...
#         Indiana  Indianapolis  Men's Street FootwearMen's ApparelWomen's Stre...
#         Iowa     Des Moines    Women's Street FootwearMen's Athletic Footwear...
#         Kansas   Wichita       Women's Athletic FootwearWomen's ApparelWomen'...
#         Michigan Detroit       Women's ApparelWomen's ApparelMen's ApparelWom...

# %% [markdown]
# ### 3. Determine which Region had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each region, state, and city.
total_sales_df = combined_sales_df.groupby(["region", "state", "city"])[["total_sales"]].sum()

# Rename the "total_sales" column to "Total Sales"

total_sales = total_sales_df.rename(columns={'total_sales': 'Total_Sales'})

# Show the top 5 results.
total_sales.head()
# Out:
#                                Total_Sales
# region  state    city
# Midwest Illinois Chicago           9797488
#         Indiana  Indianapolis      8836198
#         Iowa     Des Moines        7424011
#         Kansas   Wichita           9972864
#         Michigan Detroit          18625433

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each region, state, and city.

total_sales = pd.pivot_table(combined_sales_df, values='total_sales', index=['region', 'state', 'city'], aggfunc='sum')

# Optional: Rename the "total_sales" column to "Total Sales"


# Show the top 5 results.
total_sales.head()
# Out:
#                                total_sales
# region  state    city
# Midwest Illinois Chicago           9797488
#         Indiana  Indianapolis      8836198
#         Iowa     Des Moines        7424011
#         Kansas   Wichita           9972864
#         Michigan Detroit          18625433

# %% [markdown]
# ### 4. Determine which Retailer had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.

total_sales_retailer = combined_sales_df.groupby(['region', 'state', 'city'])['total_sales'].sum()

# Rename the "total_sales" column to "Total Sales"
#total_sales_retailer = total_sales_retailer.rename(columns={'total_sales': 'Total Sales'})

# Show the top 5 results.

total_sales_retailer.head()
# Out:
# region   state     city
# Midwest  Illinois  Chicago          9797488
#          Indiana   Indianapolis     8836198
#          Iowa      Des Moines       7424011
#          Kansas    Wichita          9972864
#          Michigan  Detroit         18625433
# Name: total_sales, dtype: int64

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
pivot_table_sales_retailer = pd.pivot_table(combined_sales_df, values='total_sales', index=['retailer', 'region', 'state', 'city'], aggfunc='sum')

# Optional: Rename the "total_sales" column to "Total Sales"


# Show the top 5 results.
pivot_table_sales_retailer.head(5)
# Out:
#                                              total_sales
# retailer region    state         city
# Amazon   Midwest   Ohio          Columbus       16835873
#          Northeast Maine         Portland        8611395
#                    Massachusetts Boston          4193590
#                    New Hampshire Manchester     10077142
#                    Vermont       Burlington     13380463

# %% [markdown]
# ### 5. Determine which Retailer Sold the Most Women's Athletic Footwear

# %%
# Filter the sales data to get the women's athletic footwear sales data.
womens_footwear_sales_data = combined_sales_df[combined_sales_df['total_sales'] == 'Women\'s Athletic Footwear']

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.

units_sold_df = womens_footwear_sales_data.groupby(['retailer', 'region', 'state', 'city'])['total_sales'].sum().reset_index()

# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"
units_sold_df = units_sold_df.rename(columns={'qty': 'Womens_Footwear_Units_Sold'})

# Show the top 5 results.
units_sold_df.head()
# Out:
# Empty DataFrame
# Columns: [retailer, region, state, city, total_sales]
# Index: []

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
pivot_table = pd.pivot_table(womens_footwear_sales_data, values='units_sold', index=['retailer', 'region', 'state', 'city'], aggfunc='sum')

# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"
pivot_table.rename(columns={'units_sold': 'Womens_Footwear_Units_Sold'}, inplace=True)

# Show the top 5 results.

pivot_table
### 5. Determine the Day with the Most Women's Athletic Footwear Sales
daily_sales = pivot_table.groupby('date')['units_sold'].sum()

# Find the day with the most women's athletic footwear sales
day_with_most_sales = daily_sales.idxmax()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 11
#       9 pivot_table
#      10 ### 5. Determine the Day with the Most Women's Athletic Footwear Sales
# ---> 11 daily_sales = pivot_table.groupby('date')['units_sold'].sum()
#      13 # Find the day with the most women's athletic footwear sales
#      14 day_with_most_sales = daily_sales.idxmax()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:8869, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8866 if level is None and by is None:
#    8867     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8869 return DataFrameGroupBy(
#    8870     obj=self,
#    8871     keys=by,
#    8872     axis=axis,
#    8873     level=level,
#    8874     as_index=as_index,
#    8875     sort=sort,
#    8876     group_keys=group_keys,
# ...

# %%
# Create a pivot table with the 'invoice_date' column is the index, and the "total_sales" as the values.
pivot_table = pd.pivot_table(combined_sales_df, index='invoice_date', values='total_sales')

# Optional: Rename the "total_sales" column to "Total Sales"
pivot_table.rename(columns={'total_sales': 'Total Sales'}, inplace=True)


# Show the table.
pivot_table

# %%
# Resample the pivot table into daily bins, and get the total sales for each day.
daily_sales = pivot_table.resample('D').sum()

# Sort the resampled pivot table in ascending order on "Total Sales".
sorted_daily_sales = daily_sales.sort_values(by='Total Sales', ascending=True)

sorted_daily_sales

# %%
# Resample the pivot table into weekly bins, and get the total sales for each week.
weekly_sales = pivot_table.resample('W').sum()

# Sort the resampled pivot table in ascending order on "Total Sales".
sorted_weekly_sales = weekly_sales.sort_values(by='Total Sales', ascending=True)

sorted_weekly_sales
